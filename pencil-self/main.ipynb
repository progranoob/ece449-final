# %%
# lr, alpha, belta, gamma
from resnet import resnet32
# from cifar import get_cifar10
# import cifar
import utils 
import pencil as pencil_lib

import torchvision.transforms as transforms
import torch
import torch.optim as optim
import torch.nn as nn
import torchvision
from scipy.special import softmax

import copy as cp
import os
import pickle
import numpy as np

# os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
# os.environ["CUDA_VISIBLE_DEVICES"] = "2"
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(torch.cuda.is_available())
if True: # Define hyper parameters
#     batch_size = 128
    batch_size = 100
    lr = 0.06
    momentum = 0.9
    weight_decay = 10e-4
    n_classes = 10
    pencil_epochs = [70, 130, 120]
#     pencil_lrs = [0.06, 0.06, 0.06]
    pencil_lrs = [0.02, 0.02, 0.02]
#     pencil_alpha, pencil_beta, pencil_gamma = 0.1, 0.4, 600
    pencil_alpha, pencil_beta, pencil_gamma = 0.1, 0.8, 200
    pencil_KL = True
    pencil_K = 10
    checkpoint = 5
    seed = 1
    train_ratio = 0.9
    asym_noise = True
    noise_ratio = 0.2
    temp_path = 'PATH_HERE'
    cifar_path = './data'

if True: # Define dataset and transforms
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])
    transform_val = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])
#     np.random.seed(seed)
#     trainset, valset = get_cifar10(cifar_path, train_ratio=train_ratio, asym=asym_noise, percent=noise_ratio, train=True, download=False, transform_train=transform_train,
#                                                transform_val=transform_val)
    trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                            download=False, transform=transform_train)
#     print(trainsetori.data[0])
#     trainset = cifar.CIFAR10_train(root='./data', train=True, download=False, transform=transform_train)
#     print(trainset.data[0])
    
    valset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                           download=False, transform=transform_val)
    trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=4)
    valloader = torch.utils.data.DataLoader(valset, batch_size=batch_size, shuffle=False, num_workers=4)
#     if start_epoch==0: # 
#         print('trainset',len(trainset))
#         trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=4)
#         valloader = torch.utils.data.DataLoader(valset, batch_size=batch_size, shuffle=False, num_workers=4)
# ######### Model checkpointing commented out
#         with open(temp_path+"trainloader"+".pkl", "wb") as file:
#             pickle.dump(trainloader,file)
#         with open(temp_path+"valloader"+".pkl", "wb") as file:
#             pickle.dump(valloader,file)
#     else: 
#         with open(temp_path+"trainloader"+".pkl", "rb") as file:
#             trainloader = pickle.load(file)
#         with open(temp_path+"valloader"+".pkl", "rb") as file:
#             valloader = pickle.load(file)
# Out:
# True

# %%
if True: # Define Model and optimizer

    # Model
    print("==> creating preact_resnet")
    model = resnet32()
    model = model.to(device)
    print('Total params: %.2fM' % (sum(p.numel() for p in model.parameters()) / 1000000.0))
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum, weight_decay=weight_decay)
# Out:
# ==> creating preact_resnet
# Total params: 0.47M

# %%
if True: # Define dict for storing results
    results = {'train':None,'val':None}
    metrics = ['acc','auprc','auroc','loss']
    for subset in results.keys(): 
        results[subset] = {metric:[] for metric in metrics}

    results['pencil_labels'], results['labels'] = [], []
    results['pencil_label_drift'], results['pencil_label_correct'] = [], []

    for i in range(len(trainset)): 
        item = trainset.__getitem__(i)
        results['labels'].append(item[1])

if True: # Define PENCIL
    pencil = pencil_lib.PENCIL(torch.tensor(results['labels']), len(trainset), n_classes, pencil_epochs, pencil_lrs, 
                                               pencil_alpha, pencil_beta, pencil_gamma, save_losses=True, use_KL=pencil_KL, K=pencil_K)

# %%
checkpoint = torch.load('weights.tar')
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
#             initepoch = checkpoint['epoch']
loss = checkpoint['loss']
with open("pencil.pkl", "rb") as file:
    pencil = pickle.load(file)
pencil.alpha=pencil_alpha
pencil.beta=pencil_beta

# %%
import time
start_epoch = 0
epochs = 320
for epoch in range(start_epoch,epochs):
    if True: # Train 
        pencil.set_lr(optimizer, epoch)
        model.train()
#         preds, label_list = [], []
#         print('a')

#         if epoch in pencil_epochs: results['pencil_labels'].append(cp.deepcopy(pencil.y_tilde))
        timestart = time.time()
        running_loss = 0.0
        total = 0
        correct = 0
        for batch_idx, (inputs, labels, inds) in enumerate(trainloader):
#             print('e')
            inputs, labels = inputs.to(device), labels.to(device, dtype= torch.int64)
            outputs = model(inputs)
            loss = pencil.get_loss(epoch, outputs, labels, inds)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            pencil.update_y_tilde(epoch, inds)
            running_loss += loss.item()
            if batch_idx % 500 == 499:  # print every 500 mini-batches
                    print('[%d, %5d] loss: %.4f' %
                          (epoch, batch_idx, running_loss / 500))
                    running_loss = 0.0
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()
                    print('Accuracy of the network on the %d tran images: %.3f %%' % (total,
                            100.0 * correct / total))
                    total = 0
                    correct = 0
#             preds.append(outputs.detach())
#             label_list.append(labels.cpu())

#         label_list = np.vstack(torch.cat(label_list).numpy())
#         preds = softmax(np.vstack(torch.cat(preds).cpu().numpy()), axis=1)
#         train_results = utils.get_performance_metrics(num_classes=n_classes,preds=preds,label_list=label_list)
#         for result in train_results.keys():
#             results['train'][result].append(train_results[result])
#         label_drift = round(sum(results['labels']==np.argmax(pencil.y_tilde,axis=1))/len(results['labels']),4)
#         label_true_corr = round(sum(results['true_labels']==np.argmax(pencil.y_tilde,axis=1))/len(results['true_labels']),4)
#         results['pencil_label_drift'].append(label_drift)
#         results['pencil_label_correct'].append(label_true_corr)

    if epoch % 5 == 4:
        correct = 0
        total = 0
        with torch.no_grad():
            for data in valloader:
                images, labels, inds = data
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        print('Accuracy of the network on the 10000 test images: %.3f %%' % (
                100.0 * correct / total))                                                          

# ########## Model checkpointing commented out
#     if checkpoint!=None and (epoch%checkpoint==0 or epoch+1 in pencil_epochs): #Save model for this epoch
#         if epoch%checkpoint==0 and epoch>start_epoch+checkpoint: 
#             os.remove(temp_path+'epoch'+str(epoch-checkpoint))
#             os.remove(temp_path+"results"+str(epoch-checkpoint)+".pkl")
#             os.remove(temp_path+"pencil"+str(epoch-checkpoint)+".pkl")
#         torch.save(model.state_dict(), temp_path+'epoch'+str(epoch))
#         with open(temp_path+"results"+str(epoch)+".pkl", "wb") as file:
#             pickle.dump(results,file)
#         with open(temp_path+"pencil"+str(epoch)+".pkl", "wb") as file:
#             pickle.dump(pencil,file)
# Out:
# [0,   499] loss: 1.8679
# Accuracy of the network on the 100 tran images: 45.000 %
# [1,   499] loss: 1.5196
# Accuracy of the network on the 100 tran images: 60.000 %
# [2,   499] loss: 1.3217
# Accuracy of the network on the 100 tran images: 69.000 %
# [3,   499] loss: 1.2022
# Accuracy of the network on the 100 tran images: 69.000 %
# [4,   499] loss: 1.1148
# Accuracy of the network on the 100 tran images: 68.000 %
# Accuracy of the network on the 10000 test images: 71.870 %
# [5,   499] loss: 1.0608
# Accuracy of the network on the 100 tran images: 67.000 %
# [6,   499] loss: 1.0169
# Accuracy of the network on the 100 tran images: 69.000 %
# [7,   499] loss: 0.9910
# Accuracy of the network on the 100 tran images: 67.000 %
# [8,   499] loss: 0.9665
# Accuracy of the network on the 100 tran images: 71.000 %
# [9,   499] loss: 0.9466
# Accuracy of the network on the 100 tran images: 78.000 %
# Accuracy of the network on the 10000 test images: 77.990 %
# [10,   499] loss: 0.9325
# Accuracy of the network on the 100 tran images: 77.000 %
# [11,   499] loss: 0.9157
# Accuracy of the network on the 100 tran images: 72.000 %
# [12,   499] loss: 0.9113
# Accuracy of the network on the 100 tran images: 77.000 %
# [13,   499] loss: 0.8972
# Accuracy of the network on the 100 tran images: 81.000 %
# [14,   499] loss: 0.8873
# Accuracy of the network on the 100 tran images: 72.000 %
# Accuracy of the network on the 10000 test images: 81.160 %
# [15,   499] loss: 0.8832
# Accuracy of the network on the 100 tran images: 74.000 %
# [16,   499] loss: 0.8776
# Accuracy of the network on the 100 tran images: 78.000 %
# [17,   499] loss: 0.8683
# Accuracy of the network on the 100 tran images: 71.000 %
# [18,   499] loss: 0.8624
# Accuracy of the network on the 100 tran images: 86.000 %
# [19,   499] loss: 0.8578
# Accuracy of the network on the 100 tran images: 77.000 %
# Accuracy of the network on the 10000 test images: 81.710 %
# [20,   499] loss: 0.8520
# Accuracy of the network on the 100 tran images: 79.000 %
# [21,   499] loss: 0.8505
# Accuracy of the network on the 100 tran images: 78.000 %
# [22,   499] loss: 0.8439
# Accuracy of the network on the 100 tran images: 77.000 %
# [23,   499] loss: 0.8447
# Accuracy of the network on the 100 tran images: 80.000 %
# [24,   499] loss: 0.8379
# Accuracy of the network on the 100 tran images: 86.000 %
# Accuracy of the network on the 10000 test images: 82.600 %
# [25,   499] loss: 0.8305
# Accuracy of the network on the 100 tran images: 79.000 %
# [26,   499] loss: 0.8308
# Accuracy of the network on the 100 tran images: 74.000 %
# [27,   499] loss: 0.8273
# Accuracy of the network on the 100 tran images: 81.000 %
# [28,   499] loss: 0.8272
# Accuracy of the network on the 100 tran images: 81.000 %
# [29,   499] loss: 0.8207
# Accuracy of the network on the 100 tran images: 76.000 %
# Accuracy of the network on the 10000 test images: 83.580 %
# [30,   499] loss: 0.8211
# Accuracy of the network on the 100 tran images: 78.000 %
# [31,   499] loss: 0.8200
# Accuracy of the network on the 100 tran images: 81.000 %
# [32,   499] loss: 0.8115
# Accuracy of the network on the 100 tran images: 74.000 %
# [33,   499] loss: 0.8107
# Accuracy of the network on the 100 tran images: 76.000 %
# [34,   499] loss: 0.8088
# Accuracy of the network on the 100 tran images: 74.000 %
# Accuracy of the network on the 10000 test images: 83.370 %
# [35,   499] loss: 0.8101
# Accuracy of the network on the 100 tran images: 77.000 %
# [36,   499] loss: 0.8081
# Accuracy of the network on the 100 tran images: 78.000 %
# [37,   499] loss: 0.7961
# Accuracy of the network on the 100 tran images: 80.000 %
# [38,   499] loss: 0.8022
# Accuracy of the network on the 100 tran images: 78.000 %
# [39,   499] loss: 0.8003
# Accuracy of the network on the 100 tran images: 77.000 %
# Accuracy of the network on the 10000 test images: 83.060 %
# [40,   499] loss: 0.7976
# Accuracy of the network on the 100 tran images: 79.000 %
# [41,   499] loss: 0.7957
# Accuracy of the network on the 100 tran images: 76.000 %
# [42,   499] loss: 0.7976
# Accuracy of the network on the 100 tran images: 79.000 %
# [43,   499] loss: 0.7901
# Accuracy of the network on the 100 tran images: 73.000 %
# [44,   499] loss: 0.7930
# Accuracy of the network on the 100 tran images: 76.000 %
# Accuracy of the network on the 10000 test images: 81.950 %
# [45,   499] loss: 0.7912
# Accuracy of the network on the 100 tran images: 77.000 %
# [46,   499] loss: 0.7873
# Accuracy of the network on the 100 tran images: 80.000 %
# [47,   499] loss: 0.7889
# Accuracy of the network on the 100 tran images: 83.000 %
# [48,   499] loss: 0.7827
# Accuracy of the network on the 100 tran images: 80.000 %
# [49,   499] loss: 0.7895
# Accuracy of the network on the 100 tran images: 79.000 %
# Accuracy of the network on the 10000 test images: 84.740 %
# [50,   499] loss: 0.7833
# Accuracy of the network on the 100 tran images: 80.000 %
# [51,   499] loss: 0.7838
# Accuracy of the network on the 100 tran images: 77.000 %
# [52,   499] loss: 0.7786
# Accuracy of the network on the 100 tran images: 86.000 %
# [53,   499] loss: 0.7799
# Accuracy of the network on the 100 tran images: 86.000 %
# [54,   499] loss: 0.7768
# Accuracy of the network on the 100 tran images: 81.000 %
# Accuracy of the network on the 10000 test images: 84.470 %
# [55,   499] loss: 0.7761
# Accuracy of the network on the 100 tran images: 82.000 %
# [56,   499] loss: 0.7777
# Accuracy of the network on the 100 tran images: 80.000 %
# [57,   499] loss: 0.7775
# Accuracy of the network on the 100 tran images: 70.000 %
# [58,   499] loss: 0.7728
# Accuracy of the network on the 100 tran images: 72.000 %
# [59,   499] loss: 0.7724
# Accuracy of the network on the 100 tran images: 79.000 %
# Accuracy of the network on the 10000 test images: 84.010 %
# [60,   499] loss: 0.7731
# Accuracy of the network on the 100 tran images: 84.000 %
# [61,   499] loss: 0.7731
# Accuracy of the network on the 100 tran images: 83.000 %
# [62,   499] loss: 0.7695
# Accuracy of the network on the 100 tran images: 77.000 %
# [63,   499] loss: 0.7723
# Accuracy of the network on the 100 tran images: 85.000 %
# [64,   499] loss: 0.7643
# Accuracy of the network on the 100 tran images: 84.000 %
# Accuracy of the network on the 10000 test images: 84.950 %
# [65,   499] loss: 0.7697
# Accuracy of the network on the 100 tran images: 81.000 %
# [66,   499] loss: 0.7685
# Accuracy of the network on the 100 tran images: 75.000 %
# [67,   499] loss: 0.7649
# Accuracy of the network on the 100 tran images: 81.000 %
# [68,   499] loss: 0.7655
# Accuracy of the network on the 100 tran images: 78.000 %
# [69,   499] loss: 0.7658
# Accuracy of the network on the 100 tran images: 82.000 %
# Accuracy of the network on the 10000 test images: 84.480 %
# C:\Users\Administrator\anaconda3\lib\site-packages\torch\nn\functional.py:2610: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# [70,   499] loss: 0.2157
# Accuracy of the network on the 100 tran images: 74.000 %
# [71,   499] loss: 0.2118
# Accuracy of the network on the 100 tran images: 80.000 %
# [72,   499] loss: 0.2198
# Accuracy of the network on the 100 tran images: 76.000 %
# [73,   499] loss: 0.2252
# Accuracy of the network on the 100 tran images: 76.000 %
# [74,   499] loss: 0.2293
# Accuracy of the network on the 100 tran images: 81.000 %
# Accuracy of the network on the 10000 test images: 81.680 %
# [75,   499] loss: 0.2252
# Accuracy of the network on the 100 tran images: 83.000 %
# [76,   499] loss: 0.2218
# Accuracy of the network on the 100 tran images: 78.000 %
# [77,   499] loss: 0.2202
# Accuracy of the network on the 100 tran images: 82.000 %
# [78,   499] loss: 0.2178
# Accuracy of the network on the 100 tran images: 77.000 %
# [79,   499] loss: 0.2151
# Accuracy of the network on the 100 tran images: 71.000 %
# Accuracy of the network on the 10000 test images: 81.230 %
# [80,   499] loss: 0.2116
# Accuracy of the network on the 100 tran images: 71.000 %
# [81,   499] loss: 0.2077
# Accuracy of the network on the 100 tran images: 73.000 %
# [82,   499] loss: 0.1981
# Accuracy of the network on the 100 tran images: 75.000 %
# [83,   499] loss: 0.1979
# Accuracy of the network on the 100 tran images: 73.000 %
# [84,   499] loss: 0.1890
# Accuracy of the network on the 100 tran images: 79.000 %
# Accuracy of the network on the 10000 test images: 79.440 %
# [85,   499] loss: 0.1861
# Accuracy of the network on the 100 tran images: 77.000 %
# [86,   499] loss: 0.1802
# Accuracy of the network on the 100 tran images: 80.000 %
# [87,   499] loss: 0.1760
# Accuracy of the network on the 100 tran images: 74.000 %
# [88,   499] loss: 0.1725
# Accuracy of the network on the 100 tran images: 74.000 %
# [89,   499] loss: 0.1640
# Accuracy of the network on the 100 tran images: 75.000 %
# Accuracy of the network on the 10000 test images: 81.710 %
# [90,   499] loss: 0.1563
# Accuracy of the network on the 100 tran images: 76.000 %
# [91,   499] loss: 0.1570
# Accuracy of the network on the 100 tran images: 75.000 %
# [92,   499] loss: 0.1479
# Accuracy of the network on the 100 tran images: 78.000 %
# [93,   499] loss: 0.1469
# Accuracy of the network on the 100 tran images: 73.000 %
# [94,   499] loss: 0.1424
# Accuracy of the network on the 100 tran images: 80.000 %
# Accuracy of the network on the 10000 test images: 81.880 %
# [95,   499] loss: 0.1362
# Accuracy of the network on the 100 tran images: 79.000 %
# [96,   499] loss: 0.1345
# Accuracy of the network on the 100 tran images: 79.000 %
# [97,   499] loss: 0.1289
# Accuracy of the network on the 100 tran images: 84.000 %
# [98,   499] loss: 0.1258
# Accuracy of the network on the 100 tran images: 74.000 %
# [99,   499] loss: 0.1220
# Accuracy of the network on the 100 tran images: 77.000 %
# Accuracy of the network on the 10000 test images: 80.720 %
# [100,   499] loss: 0.1187
# Accuracy of the network on the 100 tran images: 77.000 %
# [101,   499] loss: 0.1193
# Accuracy of the network on the 100 tran images: 77.000 %
# [102,   499] loss: 0.1139
# Accuracy of the network on the 100 tran images: 74.000 %
# [103,   499] loss: 0.1130
# Accuracy of the network on the 100 tran images: 70.000 %
# [104,   499] loss: 0.1106
# Accuracy of the network on the 100 tran images: 76.000 %
# Accuracy of the network on the 10000 test images: 81.540 %
# [105,   499] loss: 0.1116
# Accuracy of the network on the 100 tran images: 68.000 %
# [106,   499] loss: 0.1063
# Accuracy of the network on the 100 tran images: 81.000 %
# [107,   499] loss: 0.1014
# Accuracy of the network on the 100 tran images: 79.000 %
# [108,   499] loss: 0.1047
# Accuracy of the network on the 100 tran images: 82.000 %
# [109,   499] loss: 0.1000
# Accuracy of the network on the 100 tran images: 76.000 %
# Accuracy of the network on the 10000 test images: 81.530 %
# [110,   499] loss: 0.0961
# Accuracy of the network on the 100 tran images: 71.000 %
# [111,   499] loss: 0.0994
# Accuracy of the network on the 100 tran images: 74.000 %
# [112,   499] loss: 0.0961
# Accuracy of the network on the 100 tran images: 72.000 %
# [113,   499] loss: 0.0941
# Accuracy of the network on the 100 tran images: 76.000 %
# [114,   499] loss: 0.0944
# Accuracy of the network on the 100 tran images: 80.000 %
# Accuracy of the network on the 10000 test images: 82.350 %
# [115,   499] loss: 0.0926
# Accuracy of the network on the 100 tran images: 81.000 %
# [116,   499] loss: 0.0898
# Accuracy of the network on the 100 tran images: 73.000 %
# [117,   499] loss: 0.0909
# Accuracy of the network on the 100 tran images: 73.000 %
# [118,   499] loss: 0.0911
# Accuracy of the network on the 100 tran images: 77.000 %
# [119,   499] loss: 0.0875
# Accuracy of the network on the 100 tran images: 75.000 %
# Accuracy of the network on the 10000 test images: 80.210 %
# [120,   499] loss: 0.0864
# Accuracy of the network on the 100 tran images: 80.000 %
# [121,   499] loss: 0.0889
# Accuracy of the network on the 100 tran images: 73.000 %
# [122,   499] loss: 0.0889
# Accuracy of the network on the 100 tran images: 79.000 %
# [123,   499] loss: 0.0836
# Accuracy of the network on the 100 tran images: 82.000 %
# [124,   499] loss: 0.0821
# Accuracy of the network on the 100 tran images: 75.000 %
# Accuracy of the network on the 10000 test images: 80.060 %
# [125,   499] loss: 0.0849
# Accuracy of the network on the 100 tran images: 77.000 %
# [126,   499] loss: 0.0829
# Accuracy of the network on the 100 tran images: 81.000 %
# [127,   499] loss: 0.0853
# Accuracy of the network on the 100 tran images: 75.000 %
# [128,   499] loss: 0.0841
# Accuracy of the network on the 100 tran images: 81.000 %
# [129,   499] loss: 0.0812
# Accuracy of the network on the 100 tran images: 82.000 %
# Accuracy of the network on the 10000 test images: 81.600 %
# [130,   499] loss: 0.0822
# Accuracy of the network on the 100 tran images: 70.000 %
# [131,   499] loss: 0.0815
# Accuracy of the network on the 100 tran images: 75.000 %
# [132,   499] loss: 0.0801
# Accuracy of the network on the 100 tran images: 77.000 %
# [133,   499] loss: 0.0776
# Accuracy of the network on the 100 tran images: 80.000 %
# [134,   499] loss: 0.0779
# Accuracy of the network on the 100 tran images: 77.000 %
# Accuracy of the network on the 10000 test images: 81.460 %
# [135,   499] loss: 0.0793
# Accuracy of the network on the 100 tran images: 70.000 %
# [136,   499] loss: 0.0789
# Accuracy of the network on the 100 tran images: 72.000 %
# [137,   499] loss: 0.0749
# Accuracy of the network on the 100 tran images: 80.000 %
# [138,   499] loss: 0.0751
# Accuracy of the network on the 100 tran images: 78.000 %
# [139,   499] loss: 0.0773
# Accuracy of the network on the 100 tran images: 73.000 %
# Accuracy of the network on the 10000 test images: 80.910 %
# [140,   499] loss: 0.0765
# Accuracy of the network on the 100 tran images: 80.000 %
# [141,   499] loss: 0.0766
# Accuracy of the network on the 100 tran images: 75.000 %
# [142,   499] loss: 0.0775
# Accuracy of the network on the 100 tran images: 77.000 %
# [143,   499] loss: 0.0749
# Accuracy of the network on the 100 tran images: 71.000 %
# [144,   499] loss: 0.0761
# Accuracy of the network on the 100 tran images: 68.000 %
# Accuracy of the network on the 10000 test images: 80.650 %
# [145,   499] loss: 0.0753
# Accuracy of the network on the 100 tran images: 75.000 %
# [146,   499] loss: 0.0751
# Accuracy of the network on the 100 tran images: 75.000 %
# [147,   499] loss: 0.0740
# Accuracy of the network on the 100 tran images: 76.000 %
# [148,   499] loss: 0.0713
# Accuracy of the network on the 100 tran images: 77.000 %
# [149,   499] loss: 0.0765
# Accuracy of the network on the 100 tran images: 72.000 %
# Accuracy of the network on the 10000 test images: 78.990 %
# [150,   499] loss: 0.0727
# Accuracy of the network on the 100 tran images: 69.000 %
# [151,   499] loss: 0.0772
# Accuracy of the network on the 100 tran images: 70.000 %
# [152,   499] loss: 0.0730
# Accuracy of the network on the 100 tran images: 73.000 %
# [153,   499] loss: 0.0695
# Accuracy of the network on the 100 tran images: 79.000 %
# [154,   499] loss: 0.0683
# Accuracy of the network on the 100 tran images: 82.000 %
# Accuracy of the network on the 10000 test images: 79.910 %
# [155,   499] loss: 0.0739
# Accuracy of the network on the 100 tran images: 79.000 %
# [156,   499] loss: 0.0743
# Accuracy of the network on the 100 tran images: 75.000 %
# [157,   499] loss: 0.0730
# Accuracy of the network on the 100 tran images: 79.000 %
# [158,   499] loss: 0.0722
# Accuracy of the network on the 100 tran images: 68.000 %
# [159,   499] loss: 0.0715
# Accuracy of the network on the 100 tran images: 82.000 %
# Accuracy of the network on the 10000 test images: 80.870 %
# [160,   499] loss: 0.0711
# Accuracy of the network on the 100 tran images: 64.000 %
# [161,   499] loss: 0.0694
# Accuracy of the network on the 100 tran images: 76.000 %
# [162,   499] loss: 0.0718
# Accuracy of the network on the 100 tran images: 73.000 %
# [163,   499] loss: 0.0713
# Accuracy of the network on the 100 tran images: 66.000 %
# [164,   499] loss: 0.0695
# Accuracy of the network on the 100 tran images: 78.000 %
# Accuracy of the network on the 10000 test images: 79.670 %
# [165,   499] loss: 0.0713
# Accuracy of the network on the 100 tran images: 71.000 %
# [166,   499] loss: 0.0695
# Accuracy of the network on the 100 tran images: 81.000 %
# [167,   499] loss: 0.0701
# Accuracy of the network on the 100 tran images: 77.000 %
# [168,   499] loss: 0.0698
# Accuracy of the network on the 100 tran images: 75.000 %
# [169,   499] loss: 0.0680
# Accuracy of the network on the 100 tran images: 81.000 %
# Accuracy of the network on the 10000 test images: 80.710 %
# [170,   499] loss: 0.0712
# Accuracy of the network on the 100 tran images: 73.000 %
# [171,   499] loss: 0.0700
# Accuracy of the network on the 100 tran images: 76.000 %
# [172,   499] loss: 0.0713
# Accuracy of the network on the 100 tran images: 78.000 %
# [173,   499] loss: 0.0659
# Accuracy of the network on the 100 tran images: 81.000 %
# [174,   499] loss: 0.0714
# Accuracy of the network on the 100 tran images: 79.000 %
# Accuracy of the network on the 10000 test images: 79.850 %
# [175,   499] loss: 0.0693
# Accuracy of the network on the 100 tran images: 73.000 %
# [176,   499] loss: 0.0688
# Accuracy of the network on the 100 tran images: 67.000 %
# [177,   499] loss: 0.0697
# Accuracy of the network on the 100 tran images: 64.000 %
# [178,   499] loss: 0.0656
# Accuracy of the network on the 100 tran images: 79.000 %
# [179,   499] loss: 0.0669
# Accuracy of the network on the 100 tran images: 76.000 %
# Accuracy of the network on the 10000 test images: 80.350 %
# [180,   499] loss: 0.0685
# Accuracy of the network on the 100 tran images: 75.000 %
# [181,   499] loss: 0.0728
# Accuracy of the network on the 100 tran images: 70.000 %
# [182,   499] loss: 0.0669
# Accuracy of the network on the 100 tran images: 79.000 %
# [183,   499] loss: 0.0676
# Accuracy of the network on the 100 tran images: 67.000 %
# [184,   499] loss: 0.0680
# Accuracy of the network on the 100 tran images: 76.000 %
# Accuracy of the network on the 10000 test images: 77.710 %
# [185,   499] loss: 0.0667
# Accuracy of the network on the 100 tran images: 75.000 %
# [186,   499] loss: 0.0666
# Accuracy of the network on the 100 tran images: 70.000 %
# [187,   499] loss: 0.0685
# Accuracy of the network on the 100 tran images: 70.000 %
# [188,   499] loss: 0.0699
# Accuracy of the network on the 100 tran images: 69.000 %
# [189,   499] loss: 0.0700
# Accuracy of the network on the 100 tran images: 76.000 %
# Accuracy of the network on the 10000 test images: 78.030 %
# [190,   499] loss: 0.0653
# Accuracy of the network on the 100 tran images: 73.000 %
# [191,   499] loss: 0.0670
# Accuracy of the network on the 100 tran images: 70.000 %
# [192,   499] loss: 0.0658
# Accuracy of the network on the 100 tran images: 75.000 %
# [193,   499] loss: 0.0661
# Accuracy of the network on the 100 tran images: 72.000 %
# [194,   499] loss: 0.0657
# Accuracy of the network on the 100 tran images: 81.000 %
# Accuracy of the network on the 10000 test images: 80.100 %
# [195,   499] loss: 0.0657
# Accuracy of the network on the 100 tran images: 80.000 %
# [196,   499] loss: 0.0685
# Accuracy of the network on the 100 tran images: 69.000 %
# [197,   499] loss: 0.0656
# Accuracy of the network on the 100 tran images: 70.000 %
# [198,   499] loss: 0.0675
# Accuracy of the network on the 100 tran images: 72.000 %
# [199,   499] loss: 0.0671
# Accuracy of the network on the 100 tran images: 78.000 %
# Accuracy of the network on the 10000 test images: 79.620 %
# [200,   499] loss: 0.0164
# Accuracy of the network on the 100 tran images: 81.000 %
# [201,   499] loss: 0.0118
# Accuracy of the network on the 100 tran images: 75.000 %
# [202,   499] loss: 0.0119
# Accuracy of the network on the 100 tran images: 68.000 %
# [203,   499] loss: 0.0120
# Accuracy of the network on the 100 tran images: 82.000 %
# [204,   499] loss: 0.0140
# Accuracy of the network on the 100 tran images: 71.000 %
# Accuracy of the network on the 10000 test images: 81.890 %
# [205,   499] loss: 0.0175
# Accuracy of the network on the 100 tran images: 71.000 %
# [206,   499] loss: 0.0197
# Accuracy of the network on the 100 tran images: 79.000 %
# [207,   499] loss: 0.0223
# Accuracy of the network on the 100 tran images: 80.000 %
# [208,   499] loss: 0.0195
# Accuracy of the network on the 100 tran images: 76.000 %
# [209,   499] loss: 0.0180
# Accuracy of the network on the 100 tran images: 78.000 %
# Accuracy of the network on the 10000 test images: 80.730 %
# [210,   499] loss: 0.0207
# Accuracy of the network on the 100 tran images: 80.000 %
# [211,   499] loss: 0.0194
# Accuracy of the network on the 100 tran images: 78.000 %
# [212,   499] loss: 0.0191
# Accuracy of the network on the 100 tran images: 76.000 %
# [213,   499] loss: 0.0190
# Accuracy of the network on the 100 tran images: 68.000 %
# [214,   499] loss: 0.0193
# Accuracy of the network on the 100 tran images: 83.000 %
# Accuracy of the network on the 10000 test images: 80.320 %
# [215,   499] loss: 0.0183
# Accuracy of the network on the 100 tran images: 82.000 %
# [216,   499] loss: 0.0225
# Accuracy of the network on the 100 tran images: 74.000 %
# [217,   499] loss: 0.0190
# Accuracy of the network on the 100 tran images: 80.000 %
# [218,   499] loss: 0.0177
# Accuracy of the network on the 100 tran images: 74.000 %
# [219,   499] loss: 0.0189
# Accuracy of the network on the 100 tran images: 77.000 %
# Accuracy of the network on the 10000 test images: 81.210 %
# [220,   499] loss: 0.0210
# Accuracy of the network on the 100 tran images: 79.000 %
# [221,   499] loss: 0.0179
# Accuracy of the network on the 100 tran images: 78.000 %
# [222,   499] loss: 0.0185
# Accuracy of the network on the 100 tran images: 83.000 %
# [223,   499] loss: 0.0198
# Accuracy of the network on the 100 tran images: 72.000 %
# [224,   499] loss: 0.0189
# Accuracy of the network on the 100 tran images: 73.000 %
# Accuracy of the network on the 10000 test images: 80.510 %
# [225,   499] loss: 0.0203
# Accuracy of the network on the 100 tran images: 70.000 %
# [226,   499] loss: 0.0221
# Accuracy of the network on the 100 tran images: 77.000 %
# [227,   499] loss: 0.0176
# Accuracy of the network on the 100 tran images: 69.000 %
# [228,   499] loss: 0.0187
# Accuracy of the network on the 100 tran images: 83.000 %
# [229,   499] loss: 0.0197
# Accuracy of the network on the 100 tran images: 75.000 %
# Accuracy of the network on the 10000 test images: 81.880 %
# [230,   499] loss: 0.0179
# Accuracy of the network on the 100 tran images: 77.000 %
# [231,   499] loss: 0.0201
# Accuracy of the network on the 100 tran images: 88.000 %
# [232,   499] loss: 0.0185
# Accuracy of the network on the 100 tran images: 82.000 %
# [233,   499] loss: 0.0183
# Accuracy of the network on the 100 tran images: 71.000 %
# [234,   499] loss: 0.0184
# Accuracy of the network on the 100 tran images: 78.000 %
# Accuracy of the network on the 10000 test images: 81.650 %
# [235,   499] loss: 0.0195
# Accuracy of the network on the 100 tran images: 86.000 %
# [236,   499] loss: 0.0210
# Accuracy of the network on the 100 tran images: 73.000 %
# [237,   499] loss: 0.0165
# Accuracy of the network on the 100 tran images: 82.000 %
# [238,   499] loss: 0.0206
# Accuracy of the network on the 100 tran images: 79.000 %
# [239,   499] loss: 0.0206
# Accuracy of the network on the 100 tran images: 74.000 %
# Accuracy of the network on the 10000 test images: 80.800 %
# [240,   499] loss: 0.0108
# Accuracy of the network on the 100 tran images: 80.000 %
# [241,   499] loss: 0.0091
# Accuracy of the network on the 100 tran images: 72.000 %
# [242,   499] loss: 0.0085
# Accuracy of the network on the 100 tran images: 77.000 %
# [243,   499] loss: 0.0082
# Accuracy of the network on the 100 tran images: 74.000 %
# [244,   499] loss: 0.0081
# Accuracy of the network on the 100 tran images: 80.000 %
# Accuracy of the network on the 10000 test images: 83.830 %
# [245,   499] loss: 0.0081
# Accuracy of the network on the 100 tran images: 82.000 %
# [246,   499] loss: 0.0079
# Accuracy of the network on the 100 tran images: 77.000 %
# [247,   499] loss: 0.0079
# Accuracy of the network on the 100 tran images: 72.000 %
# [248,   499] loss: 0.0076
# Accuracy of the network on the 100 tran images: 81.000 %
# [249,   499] loss: 0.0076
# Accuracy of the network on the 100 tran images: 72.000 %
# Accuracy of the network on the 10000 test images: 84.050 %
# [250,   499] loss: 0.0075
# Accuracy of the network on the 100 tran images: 81.000 %
# [251,   499] loss: 0.0075
# Accuracy of the network on the 100 tran images: 82.000 %
# [252,   499] loss: 0.0075
# Accuracy of the network on the 100 tran images: 83.000 %
# [253,   499] loss: 0.0074
# Accuracy of the network on the 100 tran images: 80.000 %
# [254,   499] loss: 0.0073
# Accuracy of the network on the 100 tran images: 77.000 %
# Accuracy of the network on the 10000 test images: 84.030 %
# [255,   499] loss: 0.0072
# Accuracy of the network on the 100 tran images: 80.000 %
# [256,   499] loss: 0.0073
# Accuracy of the network on the 100 tran images: 70.000 %
# [257,   499] loss: 0.0071
# Accuracy of the network on the 100 tran images: 81.000 %
# [258,   499] loss: 0.0071
# Accuracy of the network on the 100 tran images: 80.000 %
# [259,   499] loss: 0.0072
# Accuracy of the network on the 100 tran images: 77.000 %
# Accuracy of the network on the 10000 test images: 83.920 %
# [260,   499] loss: 0.0071
# Accuracy of the network on the 100 tran images: 80.000 %
# [261,   499] loss: 0.0070
# Accuracy of the network on the 100 tran images: 79.000 %
# [262,   499] loss: 0.0068
# Accuracy of the network on the 100 tran images: 78.000 %
# [263,   499] loss: 0.0069
# Accuracy of the network on the 100 tran images: 87.000 %
# [264,   499] loss: 0.0069
# Accuracy of the network on the 100 tran images: 74.000 %
# Accuracy of the network on the 10000 test images: 84.210 %
# [265,   499] loss: 0.0069
# Accuracy of the network on the 100 tran images: 87.000 %
# [266,   499] loss: 0.0067
# Accuracy of the network on the 100 tran images: 75.000 %
# [267,   499] loss: 0.0066
# Accuracy of the network on the 100 tran images: 77.000 %
# [268,   499] loss: 0.0067
# Accuracy of the network on the 100 tran images: 80.000 %
# [269,   499] loss: 0.0066
# Accuracy of the network on the 100 tran images: 75.000 %
# Accuracy of the network on the 10000 test images: 84.060 %
# [270,   499] loss: 0.0066
# Accuracy of the network on the 100 tran images: 72.000 %
# [271,   499] loss: 0.0065
# Accuracy of the network on the 100 tran images: 79.000 %
# [272,   499] loss: 0.0065
# Accuracy of the network on the 100 tran images: 73.000 %
# [273,   499] loss: 0.0065
# Accuracy of the network on the 100 tran images: 77.000 %
# [274,   499] loss: 0.0064
# Accuracy of the network on the 100 tran images: 80.000 %
# Accuracy of the network on the 10000 test images: 83.980 %
# [275,   499] loss: 0.0065
# Accuracy of the network on the 100 tran images: 77.000 %
# [276,   499] loss: 0.0063
# Accuracy of the network on the 100 tran images: 78.000 %
# [277,   499] loss: 0.0062
# Accuracy of the network on the 100 tran images: 83.000 %
# [278,   499] loss: 0.0063
# Accuracy of the network on the 100 tran images: 83.000 %
# [279,   499] loss: 0.0062
# Accuracy of the network on the 100 tran images: 82.000 %
# Accuracy of the network on the 10000 test images: 84.280 %
# [280,   499] loss: 0.0058
# Accuracy of the network on the 100 tran images: 79.000 %
# [281,   499] loss: 0.0059
# Accuracy of the network on the 100 tran images: 79.000 %
# [282,   499] loss: 0.0058
# Accuracy of the network on the 100 tran images: 76.000 %
# [283,   499] loss: 0.0057
# Accuracy of the network on the 100 tran images: 78.000 %
# [284,   499] loss: 0.0057
# Accuracy of the network on the 100 tran images: 75.000 %
# Accuracy of the network on the 10000 test images: 84.110 %
# [285,   499] loss: 0.0058
# Accuracy of the network on the 100 tran images: 83.000 %
# [286,   499] loss: 0.0057
# Accuracy of the network on the 100 tran images: 84.000 %
# [287,   499] loss: 0.0057
# Accuracy of the network on the 100 tran images: 74.000 %
# [288,   499] loss: 0.0057
# Accuracy of the network on the 100 tran images: 83.000 %
# [289,   499] loss: 0.0056
# Accuracy of the network on the 100 tran images: 86.000 %
# Accuracy of the network on the 10000 test images: 84.060 %
# [290,   499] loss: 0.0058
# Accuracy of the network on the 100 tran images: 73.000 %
# [291,   499] loss: 0.0057
# Accuracy of the network on the 100 tran images: 76.000 %
# [292,   499] loss: 0.0056
# Accuracy of the network on the 100 tran images: 81.000 %
# [293,   499] loss: 0.0057
# Accuracy of the network on the 100 tran images: 86.000 %
# [294,   499] loss: 0.0057
# Accuracy of the network on the 100 tran images: 82.000 %
# Accuracy of the network on the 10000 test images: 84.080 %
# [295,   499] loss: 0.0057
# Accuracy of the network on the 100 tran images: 82.000 %
# [296,   499] loss: 0.0057
# Accuracy of the network on the 100 tran images: 81.000 %
# [297,   499] loss: 0.0057
# Accuracy of the network on the 100 tran images: 75.000 %
# [298,   499] loss: 0.0057
# Accuracy of the network on the 100 tran images: 77.000 %
# [299,   499] loss: 0.0056
# Accuracy of the network on the 100 tran images: 82.000 %
# Accuracy of the network on the 10000 test images: 84.050 %
# [300,   499] loss: 0.0056
# Accuracy of the network on the 100 tran images: 78.000 %
# [301,   499] loss: 0.0056
# Accuracy of the network on the 100 tran images: 81.000 %
# [302,   499] loss: 0.0055
# Accuracy of the network on the 100 tran images: 80.000 %
# [303,   499] loss: 0.0056
# Accuracy of the network on the 100 tran images: 81.000 %
# [304,   499] loss: 0.0056
# Accuracy of the network on the 100 tran images: 75.000 %
# Accuracy of the network on the 10000 test images: 84.090 %
# [305,   499] loss: 0.0056
# Accuracy of the network on the 100 tran images: 80.000 %
# [306,   499] loss: 0.0056
# Accuracy of the network on the 100 tran images: 77.000 %
# [307,   499] loss: 0.0056
# Accuracy of the network on the 100 tran images: 83.000 %
# [308,   499] loss: 0.0056
# Accuracy of the network on the 100 tran images: 83.000 %
# [309,   499] loss: 0.0055
# Accuracy of the network on the 100 tran images: 76.000 %
# Accuracy of the network on the 10000 test images: 84.100 %
# [310,   499] loss: 0.0055
# Accuracy of the network on the 100 tran images: 83.000 %
# [311,   499] loss: 0.0056
# Accuracy of the network on the 100 tran images: 73.000 %
# [312,   499] loss: 0.0055
# Accuracy of the network on the 100 tran images: 80.000 %
# [313,   499] loss: 0.0054
# Accuracy of the network on the 100 tran images: 75.000 %
# [314,   499] loss: 0.0056
# Accuracy of the network on the 100 tran images: 78.000 %
# Accuracy of the network on the 10000 test images: 84.070 %
# [315,   499] loss: 0.0054
# Accuracy of the network on the 100 tran images: 86.000 %
# [316,   499] loss: 0.0055
# Accuracy of the network on the 100 tran images: 75.000 %
# [317,   499] loss: 0.0056
# Accuracy of the network on the 100 tran images: 79.000 %
# [318,   499] loss: 0.0055
# Accuracy of the network on the 100 tran images: 79.000 %
# [319,   499] loss: 0.0055
# Accuracy of the network on the 100 tran images: 75.000 %
# Accuracy of the network on the 10000 test images: 84.130 %

# %%
torch.save({'epoch':epoch,
                        'model_state_dict':model.state_dict(),
                        'optimizer_state_dict':optimizer.state_dict(),
                        'loss':loss
                        },'weights.tar')
with open("pencil.pkl", "wb") as file:
    pickle.dump(pencil,file)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
import time
import os
import numpy as np

def test(model,device):
        correct = 0
        total = 0
        with torch.no_grad():
            for data in valloader:
                images, labels, inds = data
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        print('Accuracy of the network on the 10000 test images: %.3f %%' % (
                100.0 * correct / total))

# %%
path = 'weights.tar'
checkpoint = torch.load(path)
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
initepoch = checkpoint['epoch']
loss = checkpoint['loss']
test(model,device)
# Out:
# Accuracy of the network on the 10000 test images: 77.090 %
